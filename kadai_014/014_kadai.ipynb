# %% [markdown]
# 以下のコードを実行するとスコープに関するエラーが発生します。エラーを修正して、正しく計算結果が出力されるようにしてください。

# %%
#正しいコード　taxをグローバル化した。

price1 = 100
price2 = 200
tax = 1.1

def total():

    return price1 + price2

print (total() * tax)
# Out:
# 330.0
